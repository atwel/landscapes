# %%
##Import packages and files
from itertools import compress, product
import numpy as np
import matplotlib.pyplot as plt
import array
import random
import pandas as pd
import itertools
import operator
import importlib
#import functions defining the layered landscape
#from LayeredLandscapeFunctions import *
from Landscapes import *
import networkx as nx

# %%
##This functions takes as an input the string of file name params,e.g. "N-10_K1=3_K2=9_I=20"
#then loads in the mapping and generates the table one statistics we want:num_local_optima,num_clusters,fo_bar
def Get_Table_1_Stats(our_files,param_combo):
    loc_opt = []
    num_clusters= []
    fo_bars = []
    for file_name in our_files:
        
        if param_combo in file_name:
            print(str(file_name.replace("_mapping_Dirich_Dot.csv","_dirich.csv")))
            df_transition = pd.read_csv(str(file_name.replace("_mapping_Dirich_Dot.csv","_dirich.csv")))
            #print(df_transition.iloc[1])

            try:
                df_transition = pd.read_csv(str(file_name.replace("_mapping_Dirich_Dot.csv","_dirich.csv")))
                df_map = pd.read_csv(str(file_name))

                df_transition = df_transition.set_index('Unnamed: 0')#reset index

                Mat = Markov_Clustering(df_transition) #get markov cluster matrix
                MarkClusMatrix = nx.from_numpy_matrix(Mat) #convert to adjacency matrix undirected
                ##get the mapping and restrict it to maximas
                df_map_restricted = df_map[df_map.Maxima==1]

                #get the connected components/clusters
                G= nx.Graph(MarkClusMatrix)
                Components = list(nx.connected_components(G)) #list the components
                df_map_restricted['cluster']=0 #create variable and set to zero
                ##loop throught the components and assign clusters
                j=0 #number to index number of components
                NumComp = len(Components)
                for comp in Components:
                    for i in comp:
                        df_map_restricted['cluster'].iloc[i]=j
                    j+=1


                #identify cluster with the global maxima
                Cluster_of_Maxima = df_map_restricted.loc[df_map_restricted.Fitness.idxmax()].cluster
                ##set the table variables
                num_local_optima = len(df_map_restricted)
                num_clust = NumComp
                fo_bar = len(df_map_restricted[df_map_restricted.cluster ==Cluster_of_Maxima ]) / num_local_optima
                loc_opt.append(num_local_optima)
                num_clusters.append(num_clust)
                fo_bars.append(fo_bar)
            except:
                pass
            
    return [np.average(loc_opt),np.std(loc_opt),np.average(num_clusters),np.std(num_clusters),np.average(fo_bars),np.std(fo_bars)]

# %%
import glob
import re
import os.path
os.getcwd()
#os.chdir('afs-home/Dot_Dirichlet_Sims')
our_files = glob.glob("*_mapping_Dirich_Dot.csv")

# %%
all_files
# Out:
# ['K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=10',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=1',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=2',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=3',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=4',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=5',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=6',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=7',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=8',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9',
#  'K=9']

# %%
all_files = []
for file in our_files:
    
    if re.findall("K=10",file):
        all_files.extend(re.findall("K=\d\d",file))
    else:
        all_files.extend(re.findall("K=\d",file))

# %%
List_file_params = set(all_files)
List_file_params
# Out:
# ['N-10_K=10_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=10_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=1_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=2_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=3_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=4_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=5_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=6_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=7_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=8_I=9_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=1_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=2_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=3_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=4_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=5_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=6_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=7_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=8_mapping_Dirich_Dot.csv',
#  'N-10_K=9_I=9_mapping_Dirich_Dot.csv']

# %%
##Get a list of file names

##loop over them
Table_Stats = df_ = pd.DataFrame(index=List_file_params, columns=['AVG num_local_optima',"SD num_optima",'AVG num_clusters', "SD clusters",'AVG fo_bar',"SD fo_bar"])

for params in List_file_params:
    print(params)
    Table_Stats.loc[params] = Get_Table_1_Stats(our_files,params)
# Out:
# K=2
# N-10_K=2_I=1_dirich.csv
# N-10_K=2_I=2_dirich.csv
# N-10_K=2_I=3_dirich.csv
# N-10_K=2_I=4_dirich.csv
# N-10_K=2_I=5_dirich.csv
# /Users/adrianapaza/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/adrianapaza/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# N-10_K=2_I=6_dirich.csv
# N-10_K=2_I=7_dirich.csv
# N-10_K=2_I=8_dirich.csv
# N-10_K=2_I=9_dirich.csv
# K=10
# N-10_K=10_I=1_dirich.csv
# N-10_K=10_I=2_dirich.csv
# N-10_K=10_I=3_dirich.csv
# N-10_K=10_I=4_dirich.csv
# N-10_K=10_I=5_dirich.csv
# N-10_K=10_I=6_dirich.csv
# N-10_K=10_I=7_dirich.csv
# N-10_K=10_I=8_dirich.csv
# N-10_K=10_I=9_dirich.csv
# K=4
# N-10_K=4_I=1_dirich.csv
# N-10_K=4_I=2_dirich.csv
# N-10_K=4_I=3_dirich.csv
# N-10_K=4_I=4_dirich.csv
# N-10_K=4_I=5_dirich.csv
# N-10_K=4_I=6_dirich.csv
# N-10_K=4_I=7_dirich.csv
# N-10_K=4_I=8_dirich.csv
# N-10_K=4_I=9_dirich.csv
# K=7
# N-10_K=7_I=1_dirich.csv
# N-10_K=7_I=2_dirich.csv
# N-10_K=7_I=3_dirich.csv
# N-10_K=7_I=4_dirich.csv
# N-10_K=7_I=5_dirich.csv
# N-10_K=7_I=6_dirich.csv
# N-10_K=7_I=7_dirich.csv
# N-10_K=7_I=8_dirich.csv
# N-10_K=7_I=9_dirich.csv
# K=9
# N-10_K=9_I=1_dirich.csv
# N-10_K=9_I=2_dirich.csv
# N-10_K=9_I=3_dirich.csv
# N-10_K=9_I=4_dirich.csv
# N-10_K=9_I=5_dirich.csv
# N-10_K=9_I=6_dirich.csv
# N-10_K=9_I=7_dirich.csv
# N-10_K=9_I=8_dirich.csv
# N-10_K=9_I=9_dirich.csv
# K=5
# N-10_K=5_I=1_dirich.csv
# N-10_K=5_I=2_dirich.csv
# N-10_K=5_I=3_dirich.csv
# N-10_K=5_I=4_dirich.csv
# N-10_K=5_I=5_dirich.csv
# N-10_K=5_I=6_dirich.csv
# N-10_K=5_I=7_dirich.csv
# N-10_K=5_I=8_dirich.csv
# N-10_K=5_I=9_dirich.csv
# K=3
# N-10_K=3_I=1_dirich.csv
# N-10_K=3_I=2_dirich.csv
# N-10_K=3_I=3_dirich.csv
# N-10_K=3_I=4_dirich.csv
# N-10_K=3_I=5_dirich.csv
# N-10_K=3_I=6_dirich.csv
# N-10_K=3_I=7_dirich.csv
# N-10_K=3_I=8_dirich.csv
# N-10_K=3_I=9_dirich.csv
# K=8
# N-10_K=8_I=1_dirich.csv
# N-10_K=8_I=2_dirich.csv
# N-10_K=8_I=3_dirich.csv
# N-10_K=8_I=4_dirich.csv
# N-10_K=8_I=5_dirich.csv
# N-10_K=8_I=6_dirich.csv
# N-10_K=8_I=7_dirich.csv
# N-10_K=8_I=8_dirich.csv
# N-10_K=8_I=9_dirich.csv
# K=6
# N-10_K=6_I=1_dirich.csv
# N-10_K=6_I=2_dirich.csv
# N-10_K=6_I=3_dirich.csv
# N-10_K=6_I=4_dirich.csv
# N-10_K=6_I=5_dirich.csv
# N-10_K=6_I=6_dirich.csv
# N-10_K=6_I=7_dirich.csv
# N-10_K=6_I=8_dirich.csv
# N-10_K=6_I=9_dirich.csv
# K=1
# N-10_K=10_I=1_dirich.csv
# N-10_K=10_I=2_dirich.csv
# N-10_K=10_I=3_dirich.csv
# N-10_K=10_I=4_dirich.csv
# N-10_K=10_I=5_dirich.csv
# N-10_K=10_I=6_dirich.csv
# N-10_K=10_I=7_dirich.csv
# N-10_K=10_I=8_dirich.csv
# N-10_K=10_I=9_dirich.csv
# N-10_K=1_I=1_dirich.csv
# N-10_K=1_I=2_dirich.csv
# N-10_K=1_I=3_dirich.csv
# N-10_K=1_I=4_dirich.csv
# N-10_K=1_I=5_dirich.csv
# N-10_K=1_I=6_dirich.csv
# N-10_K=1_I=7_dirich.csv
# N-10_K=1_I=8_dirich.csv
# N-10_K=1_I=9_dirich.csv

# %%
#rearaange from K=1 to 10
Table_stats = Table_Stats.sort_index()
Table_stats.iloc[1,:]
Table_stats=Table_stats.append(Table_stats.iloc[1,:])
Table_stats=Table_stats.iloc[0:1,:].append(Table_stats.iloc[2:11,:])
Table_stats

# %%
Table_stats
# Out:
#      AVG num_local_optima SD num_optima AVG num_clusters SD clusters  \
# K=1               30.8333        27.496          1.66667     1.05409
# K=2                    41        7.9861          2.22222    0.916246
# K=3               25.1111        6.0451          1.66667    0.816497
# K=4               19.7778       4.13058          1.55556    0.955814
# K=5               14.7778       3.35916          1.77778     0.41574
# K=6               11.2222       3.39208          1.33333    0.471405
# K=7               7.22222       2.04275          1.22222     0.41574
# K=8               6.44444       3.02255          1.33333    0.471405
# K=9               6.77778       1.87248                1           0
# K=10              3.77778       1.81217          1.11111     0.31427
#
#      AVG fo_bar  SD fo_bar
# K=1    0.970171  0.0525837
# K=2    0.958149  0.0343467
# K=3    0.959643  0.0594973
# K=4    0.926135    0.16249
# K=5    0.934939  0.0445847
# K=6    0.964868   0.053673
# K=7    0.877778   0.229868
# K=8     0.92284   0.154814
# K=9           1          0
# K=10   0.977778  0.0628539
